# %%
from glob import glob
from lxml import etree

# %%
files = glob('xml/*.xml')
NSMAP = {None : "http://www.tei-c.org/ns/1.0"}

# %%
for f in files:
    tree = etree.parse(f)
    main_title = tree.find("teiHeader/fileDesc/titleStmt/title", NSMAP).text
    #for w in tree.find()
    #for t in tree.iter():
     #   print(t.tag)
    
    for tag in tree.iter():
       print(tree.getelementpath(tag))
# Out:
# .
# {http://www.tei-c.org/ns/1.0}teiHeader
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc/{http://www.tei-c.org/ns/1.0}titleStmt
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc/{http://www.tei-c.org/ns/1.0}titleStmt/{http://www.tei-c.org/ns/1.0}title
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc/{http://www.tei-c.org/ns/1.0}titleStmt/{http://www.tei-c.org/ns/1.0}respStmt[1]
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc/{http://www.tei-c.org/ns/1.0}titleStmt/{http://www.tei-c.org/ns/1.0}respStmt[1]/{http://www.tei-c.org/ns/1.0}resp
# {http://www.tei-c.org/ns/1.0}teiHeader/{http://www.tei-c.org/ns/1.0}fileDesc/{http://www.tei-c.org/ns/1.0}titleStmt/{http://www.tei-c.org/ns/1.0}respStmt[1]/{http://www.tei-c.org/ns/1.0}name
# ...
